# %% [markdown]
# # ***data types***

# %%
name="shreya"
print(type(name))
# Out:
# <class 'str'>

# %%
name2="shreya & 123 & rr"
print(type(name2))
# Out:
# <class 'str'>

# %% [markdown]
# sequence data type list tuples range

# %%
lis2=['shreya','123','30.45']
type(lis)
print(lis)
# Out:
# ['apple', '200', 'India']

# %%
lis= ['apple', '200', 'India']
lis2=['shreya','123','30.45']
print(lis)
print(lis2)
print(len(lis))
print(len(lis2))
lis3= lis+lis2
print (lis3)
print(len(lis3))
# Out:
# ['apple', '200', 'India']
# ['shreya', '123', '30.45']
# 3
# 3
# ['apple', '200', 'India', 'shreya', '123', '30.45']
# 6

# %%
lis2.append("hubli")

# %%
lis2
# Out:
# ['shreya', '123', '30.45', 'hubli']

# %%
lis2.append("shreya")
lis2
# Out:
# ['shreya', '123', '30.45', 'hubli', 'shreya']

# %%
lis2.clear()

# %%
lis2
# Out:
# []

# %%
lis=['kk','aa','kle','ggg']
lis[0]
# Out:
# 'kk'

# %%
lis[2]
# Out:
# 'kle'

# %%
lis[1]
# Out:
# 'aa'

# %%
lis.sort()

# %%
lis
# Out:
# ['aa', 'ggg', 'kk', 'kle']

# %%
num1=60
num2=50.89
num3=4j
num4=-99
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>
